# %% [markdown]
# # Welcome to the Python Playground \n\nUse this notebook to explore the CSV you downloaded from the micro-case app.\n\n**How to load a file:** In the left sidebar, click **File Browser ▶ Upload Files**, select your CSV, then run the cells below.

# %%
import pandas as pd\n# 👇 If your file has a different name, change it here\nFILENAME = 'sample.csv'\ndf = pd.read_csv(FILENAME)\ndf.head()

# %%
# Quick sanity checks\ndf.info()

# %%
# Example: average demand by DC\ndf.groupby('dc')['avg_wk_demand_units'].mean().reset_index().rename(\n    columns={'avg_wk_demand_units':'avg_demand_units'}\n)
